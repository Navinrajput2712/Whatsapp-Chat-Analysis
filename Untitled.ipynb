# %%
import re
import pandas as pd

# %%
f = open('WhatsApp Chat with Aniket Raje.txt','r',encoding='utf-8')

# %%
data = f.read()

# %%
pattern = r'\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
messages = re.split(pattern, data)[1:]
messages
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'navinrajput: Hii aniket bro\n',
#  'Aniket Raje: Bolo bhai\n',
#  'navinrajput: Bro tumne web development chalu hai\n',
#  'Aniket Raje: Ha\n',
#  'Aniket Raje: Abhi nextjs kar raha hu\n',
#  'navinrajput: Kha se kar raha ho\n',
#  'Aniket Raje: Hitesh choudhary - chai aur code\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Haa dekha ho\n',
#  'navinrajput: Or data science kaisa chal raha hai\n',
#  'Aniket Raje: Best hai unka playlist\n',
#  'navinrajput: Haa dekha bro\n',
#  'Aniket Raje: Thik bas todha break liya. Is month feb main deep learning start karne ka socha hai\n',
#  'navinrajput: Mai bhi bro machine learing start karo ga\n',
#  'Aniket Raje: Aap abhi web development kar rahe ho kya\n',
#  'navinrajput: Bhai wo kaisa hai ki week mai sunday sunday web development ke concept sikha tha ho baki din data science or coding karta ho\n',
#  'Aniket Raje: Badiya hai apka\n',
#  'navinrajput: Haa bro\n',
#  'Aniket Raje: Kitna hua hai abhi tak apka\n',
#  'navinrajput: Bro mai abhi thoda college ki waja se time set nhi hota hai isa liye maine abhi thoda break.chal raha time.milta hai to karta ho coding wagera\n',
#  'Aniket Raje: Ya big problem hai. Same mera bhi yahi hai\n',
#  'navinrajput: Tum btech kar raha ho\n',
#  'Aniket Raje: Ha\n',
#  'navinrajput: Kha se\n',
#  'Aniket Raje: Bharati vidyapeeth navi mumbai\n',
#  'Aniket Raje: Abhishek kar raha hai vhi se\n',
#  'navinrajput: Mai LJ engineering college se kar raha ho mca\n',
#  'Aniket Raje: Cholo bye\n',
#  'navinrajput: Hii bro\n',
#  'Aniket Raje: Bolo bro\n',
#  'navinrajput: Bro deep learing ka koi hands notes hai tumhare pass\n',
#  'Aniket Raje: Hand written nhi hai\n',
#  'navinrajput: Tu kaisa hai\n',
#  'Aniket Raje: Mere nhi hai online mile the\n',
#  'Aniket Raje: Rukho bhejta hu\n',
#  'Aniket Raje: <Media omitted>\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Bhai sorry mil nhi rahe\n',
#  'Aniket Raje: Mil jayega tabh bhej dunga\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Hii\n',
#  'Aniket Raje: Hi bro\n',
#  'navinrajput: Bro ml koi project bana hai tumne\n',
#  'Aniket Raje: Ha\n',
#  'navinrajput: Kon sa\n',
#  'Aniket Raje: Maine navi mumbai ke jitne bhi flats hai unka price and location extra scrap kiya alag alag website se\n',
#  'Aniket Raje: Uske upar data analysis kiya\n',
#  'Aniket Raje: Aur ml models train kiye\n',
#  'Aniket Raje: Usme random forest sabse acha result deh raha tha\n',
#  'Aniket Raje: Around 78 %\n',
#  'navinrajput: Ml youtube se hi pada tha\n',
#  'Aniket Raje: Ha 100days campus\n',
#  'navinrajput: Haa\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Kya hua\n',
#  'Aniket Raje: Kuch kaam tha\n',
#  'Aniket Raje: http://navimumbai.pythonanywhere.com/\n',
#  'Aniket Raje: Ye vo model hai\n',
#  'Aniket Raje: Deploye kiya hai django main\n',
#  'Aniket Raje: Aur kiye hai kaggle dataset pe\n',
#  'navinrajput: Bro mai soch raha ho apne group mai har saturday or sunday daily lecture le koi jisko jo aata hai wo bata te tu jaldi cover ho ga\n',
#  'Aniket Raje: Ha lekin campusx wala best hai, instead teaching hume doubt solve karne chahiye\n',
#  'Aniket Raje: Ek dusre ke\n',
#  'Aniket Raje: Aur koi aur Padhygea toh kuch kuch chut jaayega\n',
#  'navinrajput: Haa wo hi or kuch project bhi discussion\n',
#  'Aniket Raje: Apka kitna hua hai\n',
#  'Aniket Raje: Ml\n',
#  'navinrajput: Abhi start karo ga\n',
#  'Aniket Raje: Jitna jaldi ho sake utne jaldi finish karo\n',
#  'Aniket Raje: Kyuki kitne bhi deep main padha na bhul jaayenge\n',
#  'Aniket Raje: Hum\n',
#  'navinrajput: Mujhe project chahiye taki ml.sikha te rahu or project banata rahu\n',
#  'Aniket Raje: Islye pehele course complete karo jaldi se jaldi\n',
#  'navinrajput: Ok\n',
#  'navinrajput: hii\n',
#  'Aniket Raje: Hi bro\n',
#  'navinrajput: bro tum free rahte 1 ya 2 hour daily\n',
#  'Aniket Raje: Abhi toh nhi rehta hu\n',
#  'Aniket Raje: Clg ka work rehta hai\n',
#  'Aniket Raje: Is sem todha busy rahunga\n',
#  'Aniket Raje: Kya hua\n',
#  'navinrajput: nhi tu mujhe ml sikha de\n',
#  'Aniket Raje: Bhai main khud bhul chuka hu\n',
#  'Aniket Raje: Muje practice karni hogi\n',
#  'Aniket Raje: Todhi revision bhi karna hoga\n',
#  'navinrajput: ok\n',
#  'Aniket Raje: Bhai apko campusx ka samj nhi arha kya\n',
#  'navinrajput: nhi bro wo problem nhi hai\n',
#  'navinrajput: wo kya mujhe khali saam ko time milta hai nus padhne baaki tu pura din college mai nikal jata hai or college work bhi karna rahata hai isa liye bola\n',
#  'Aniket Raje: Same bro ye clg ke vaje se time nhi milta\n',
#  'navinrajput: haa\n',
#  'Aniket Raje: apne start kiya hai kya\n',
#  'navinrajput: haa start tu kiya\n',
#  'Aniket Raje: Daily 1-2 hrs bhut hai\n',
#  'navinrajput: haa\n',
#  'Aniket Raje: Practice aur notes important hai\n',
#  'Aniket Raje: Baad main break ke baad bhul jate hai\n',
#  'Aniket Raje: Mere sath vhi hua\n',
#  'Aniket Raje: Lekin revision main time nhi lagega\n',
#  'navinrajput: mera tu sep month  placement start hoga\n',
#  'Aniket Raje: Aap konse year main ho abhi\n',
#  'navinrajput: mai mca kar raha hu\n',
#  'navinrajput: abhi sem 2 chalu hai\n',
#  'Aniket Raje: Bhai apka development main kuch hua hai kya\n',
#  'Aniket Raje: Mere college main 4-5 bache hai vo bhut ache hai machine learning main phir bhi une data anylst wala role mila hai\n',
#  'Aniket Raje: Ek ka IBM main laga hai use 9 LPA de rahe hai\n',
#  'navinrajput: haa bhai web development aata bus wo react or node or express kar lo tu pur mere ko python mai web development aata hai\n',
#  'Aniket Raje: Main abhi react and next js hi kar raha hu\n',
#  'navinrajput: hmm\n',
#  'navinrajput: Bro kal doudt sloving rakhe kya\n',
#  'Aniket Raje: Ha rakte hai\n',
#  'Aniket Raje: Sabh ko puch ke dekte hai kal\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Hii\n',
#  'Aniket Raje: Hi bro\n',
#  'navinrajput: Bro maine pdf beji thi wo dekha\n',
#  'Aniket Raje: Nhi bro muje time nhi mila abhi dekhta hu\n',
#  'navinrajput: Bro dekha\n',
#  'Aniket Raje: Ha\n',
#  'navinrajput: Bro karne jaisa hai\n',
#  'Aniket Raje: Ha\n',
#  'Aniket Raje: Hume saare subject hai\n',
#  'navinrajput: Kyuki ismai wo sare subject jo hum abhi padha raha hai\n',
#  'Aniket Raje: Ha\n',
#  'navinrajput: Tu try kare kya exam de iski\n',
#  'Aniket Raje: Abhi toh nhi\n',
#  'Aniket Raje: Todha confidence chaiye\n',
#  'navinrajput: Bro abhi nhi next year\n',
#  'Aniket Raje: Dekhunga\n',
#  'Aniket Raje: Pakka nhi hai\n',
#  'navinrajput: Tumhara placement kab hai\n',
#  'Aniket Raje: Time hai\n',
#  'Aniket Raje: Main abhi 2 nd year main hu\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Mera tu isa saal hai\n',
#  'Aniket Raje: Oh\n',
#  'navinrajput: Hmm\n',
#  'Aniket Raje: Aapke college main companies arhi hai kya\n',
#  'navinrajput: Bro senior ka tu ho gaya abhi humara sep se chalu ho ga\n',
#  'Aniket Raje: Aap abhi 3rd year main ho kya\n',
#  'navinrajput: Bro mera tu mca hai <This message was edited>\n',
#  'Aniket Raje: Ok\n',
#  'Aniket Raje: Is saal jobs kam hone wala hai\n',
#  'Aniket Raje: Specialy software and machine learning field main\n',
#  'navinrajput: Haa bro ye hi problem hai\n',
#  'Aniket Raje: Aap data anylst pe focus karo todha\n',
#  'Aniket Raje: Chances jyda hai vha pe mil ne ke\n',
#  'Aniket Raje: Mere clg se 3,4 bacho ka ibm main laga hai\n',
#  'Aniket Raje: Around 8lpa hai\n',
#  'navinrajput: Bro mai tu dsa bhi kar raha aur web dev bhi\n',
#  'navinrajput: Ye tu bro isa mai hi ho jaye ga\n',
#  'Aniket Raje: All the best bhai. Acha placement lage apka\n',
#  'navinrajput: Hmm bro\n',
#  'navinrajput: Bro ye wani yavatmai maharastra mai kha par aaya hai\n',
#  'Aniket Raje: Yavatmal kya\n',
#  'navinrajput: Wani hai\n',
#  'navinrajput: Maharastra mak\n',
#  'Aniket Raje: Ha\n',
#  'Aniket Raje: Nagpur side main\n',
#  'Aniket Raje: Kya hua\n',
#  'navinrajput: Hai kuch kaam hai bhai\n',
#  'Aniket Raje: Nagpur ke paas hai\n',
#  'Aniket Raje: I guess\n',
#  'navinrajput: Tumhare yaha se kitna dur padega\n',
#  'Aniket Raje: Main navi mumbai main rehta hu\n',
#  'Aniket Raje: Bhut dur hai\n',
#  'navinrajput: ok\n',
#  'navinrajput: Hii\n',
#  'Aniket Raje: Hi bro\n',
#  'navinrajput: Bro ml ke notes hai tumhare pass\n',
#  'Aniket Raje: Nahi\n',
#  'Aniket Raje: Main ml mastery book ko refer karta hu\n',
#  'navinrajput: Tu book bejo na bro\n',
#  'Aniket Raje: <Media omitted>\n',
#  'Aniket Raje: <Media omitted>\n',
#  'navinrajput: Ok bro\n',
#  'navinrajput: Bro dl start kiya\n',
#  'Aniket Raje: Ha\n',
#  'Aniket Raje: Backpropagation pe atka hu\n',
#  'navinrajput: Bro mlops kiya hai tumne ki baki hai\n',
#  'Aniket Raje: Mlops nhi kiya\n',
#  'Aniket Raje: Vo end main\n',
#  'navinrajput: Hmm\n',
#  'navinrajput: hi\n',
#  'Aniket Raje: Hi\n',
#  'navinrajput: bro math ka topic complete kiya hai ya math kuch padha\n',
#  'Aniket Raje: Matlab\n',
#  'navinrajput: jo data science ke use hota hai math wo pdha hai ki baki hai\n',
#  'Aniket Raje: Mere sabh hua hai kyuki mere syllabus main sabh aiml ka maths hai\n',
#  'Aniket Raje: 5 subject the maths ke\n',
#  'navinrajput: btech ke syllabus mai\n',
#  'Aniket Raje: Ha\n',
#  'Aniket Raje: Utna maths ki abhi tak need nhi hui lekin\n',
#  'navinrajput: bhai wo tu maine bhi padha hai but thoda practice ke liye thodha karna hai revision karna hai\n',
#  'Aniket Raje: 100days of machine learning playlist main kuch maths use nhi hora\n',
#  'Aniket Raje: Bas linear algebra\n',
#  'Aniket Raje: Basic derivative\n',
#  'navinrajput: haa wo hi bol raha\n',
#  'Aniket Raje: And vector Algebra\n',
#  'Aniket Raje: Itne hi topic important hai\n',
#  'Aniket Raje: 3brown1blue channel ko refer karo\n',
#  'navinrajput: waise tu math tu padha hai but interview se phele padhan hai\n',
#  'Aniket Raje: Utna maths pe abhi focus mat karo\n',
#  'Aniket Raje: Ha use time hi padhna\n',
#  'navinrajput: ok\n',
#  'navinrajput: hii\n',
#  'navinrajput: Bro reply karo\n',
#  'Aniket Raje: Hi kya hua\n',
#  'navinrajput: Bro jo tumne house price  wala project banaya tha uska code bejna to\n',
#  'Aniket Raje: Ok\n',
#  'Aniket Raje: Lekin bhut sare files hai\n',
#  'Aniket Raje: Thik se code nhi kiya tha maine\n',
#  'Aniket Raje: Google Drive ka link bhejta hu\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: 5 min main bhejta hu\n',
#  'Aniket Raje: https://drive.google.com/drive/folders/1VXYEuQaT9pmo9ShGhlx85iXp6UeasXfd\n',
#  'navinrajput: Bhai wo course ka pranav bol raha uske baare socha kuch\n',
#  'Aniket Raje: Bhai mere dost ke pass hai vo course\n',
#  'Aniket Raje: Humne liya tha 1year phele hi\n',
#  'Aniket Raje: Utna khaas kuch nhi hai usme\n',
#  'navinrajput: Esa\n',
#  'navinrajput: Hii\n',
#  'Aniket Raje: Hi\n',
#  'navinrajput: Bhai kuch bol kyu nhi raha hu\n',
#  'Aniket Raje: Bhai bas sunn raha hu\n',
#  'Aniket Raje: Kuch rahega toh bol dunga\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Apka linked in url send karo\n',
#  'navinrajput: Wait\n',
#  'navinrajput: https://www.linkedin.com/in/navin-rajput-036894235/\n',
#  'navinrajput: Apni id share linkdin ki\n',
#  'Aniket Raje: https://www.linkedin.com/in/aniket-raje?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app\n',
#  'navinrajput: Bro react koi login register page mujhe backend mai connect karna hai node js se\n',
#  'Aniket Raje: Ok\n',
#  'navinrajput: Bejna hai tu\n',
#  'Aniket Raje: Dekta hu\n',
#  'navinrajput: Hmm\n',
#  'Aniket Raje: Main abhi bhar hu\n',
#  'navinrajput: Thik hai bej dena bro raat tak\n',
#  'Aniket Raje: Mila toh bhen dunga\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Maine react and node js abhi tak connect nhi kiya i guess\n',
#  'Aniket Raje: Ise pehle main django karta tha\n',
#  'Aniket Raje: Django ka hai authentication system\n',
#  'navinrajput: Nhi mujhe kya react mai mil jaye ga na tu mai try karo ga\n',
#  'Aniket Raje: Chai aur code ke channel pe hai i guess\n',
#  'Aniket Raje: Video lec\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Tu dekhata ho\n',
#  'Aniket Raje: Ha\n',
#  'Aniket Raje: Maine react abhi start kiya hai\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Hii bro\n',
#  'Aniket Raje: Bolo bhai\n',
#  'navinrajput: Bhai tumne intership ka socha mujhe kari hai isa kiye puccha rha hu\n',
#  'Aniket Raje: Nhi socha abhi tak\n',
#  'navinrajput: bro chalu karte hai ha\n',
#  'Aniket Raje: 1,2 project bana ne ke baad apply karunga\n',
#  'navinrajput: tu kon sa bana raha hu\n',
#  'Aniket Raje: Socha nhi hai abhi\n',
#  'navinrajput: mera ek ready hai jo iot banaya tha\n',
#  'Aniket Raje: Mera exam hone ke baad start karunga\n',
#  'navinrajput: ok\n',
#  'navinrajput: Bro google collab ka use kar ke bhi project bana skte hai\n',
#  'Aniket Raje: Main collab hi use karta hu\n',
#  'navinrajput: Bro usko online hi use kar skte hau\n',
#  'Aniket Raje: Ha\n',
#  'navinrajput: Bro jupter notebook use nhi karte hu kya\n',
#  'Aniket Raje: Ha\n',
#  'Aniket Raje: Kabhi kabhi use karta hu\n',
#  'Aniket Raje: Mostly google collab\n',
#  'navinrajput: Bro iska desktop version hai kya kyu ki mai bhut kaam use collab\n',
#  'Aniket Raje: Nhi pata\n',
#  'Aniket Raje: Main browser main use karta hu\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Hii\n',
#  'Aniket Raje: Hello\n',
#  'navinrajput: Bro python base koi project idea hai using flask\n',
#  'Aniket Raje: Video streaming website\n',
#  'Aniket Raje: Multimedia sharing web app\n',
#  'navinrajput: Ok\n',
#  'navinrajput: bro tumne bana hai\n',
#  'navinrajput: bro ye tu amzone prime ya netflix ya hotstart jaisa webiste hoga\n',
#  'navinrajput: bhai jo tumne project bataya hai unki website ki koi template padi ho tu bejna na\n',
#  'navinrajput: ya phir mai netflix ki use karlo\n',
#  'Aniket Raje: Bhai,Nhi hai mere paas.\n',
#  'navinrajput: Tumne banaya hai\n',
#  'Aniket Raje: Nhi\n',
#  'navinrajput: Ye batana\n',
#  'Aniket Raje: Main baad main try karne wala hu\n',
#  'navinrajput: Bro\n',
#  'Aniket Raje: Nhi hai bhai\n',
#  'Aniket Raje: Ha\n',
#  'Aniket Raje: Ekdam nhi par\n',
#  'Aniket Raje: Backend se video web socket ya webrtc through\n',
#  'Aniket Raje: Send hogi\n',
#  'navinrajput: Bro inki api use karke movies ka data dal de tu\n',
#  'Aniket Raje: Ha vo bhi acha rahega\n',
#  'navinrajput: Hmm\n',
#  'navinrajput: Bro ya video streaming mai anime ka bana du thofa unqui lage ga\n',
#  'Aniket Raje: Ha bhai\n',
#  'navinrajput: But uski api kha se laoga bus ye problem hai\n',
#  'Aniket Raje: Rapid api pe check karo ek baar\n',
#  'Aniket Raje: Koi anime related api mili\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Toh usko project banv\n',
#  'navinrajput: Thik hai\n',
#  'Aniket Raje: Anime suggestions type yese kuch\n',
#  'navinrajput: Ol\n',
#  'navinrajput: Hii bro\n',
#  'Aniket Raje: Hi\n',
#  'navinrajput: Bro abhi tak kitne project bana hai tumne\n',
#  'Aniket Raje: 2-3\n',
#  'Aniket Raje: Food ordering website dango - incomplete hai abhi\n',
#  'navinrajput: Kon kon sa\n',
#  'Aniket Raje: ISP service management\n',
#  'navinrajput: Ye kispar banaya djangi\n',
#  'Aniket Raje: Php\n',
#  'Aniket Raje: https://foodbee.pythonanywhere.com/\n',
#  'navinrajput: Django mai banya tha\n',
#  'navinrajput: Koi\n',
#  'Aniket Raje: .\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Isp mai kya hota hai\n',
#  'Aniket Raje: Internet service plan\n',
#  'Aniket Raje: Like plan renewal\n',
#  'Aniket Raje: Employee management\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Conplaints register\n',
#  'navinrajput: Iska koi resource hai\n',
#  'Aniket Raje: Nhi pata muje\n',
#  'Aniket Raje: Main koi video dekha tha\n',
#  'Aniket Raje: I guess neetcode. io wala\n',
#  'navinrajput: Kha par\n',
#  'Aniket Raje: .\n',
#  'navinrajput: Youtube par\n',
#  'Aniket Raje: Nhi uske course main\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Telegram pe tha\n',
#  'Aniket Raje: Pehle\n',
#  'Aniket Raje: Abhi nhi hoga shayd\n',
#  'navinrajput: Nhi matlab video stream tu netflix ki tarha ho jaye ga\n',
#  'Aniket Raje: Ha\n',
#  'Aniket Raje: Bro web socket ya webrtc sikho\n',
#  'Aniket Raje: Use kam ho jayega\n',
#  'navinrajput: Or multmedia sharing ka bataoo\n',
#  'Aniket Raje: Vo bhi peer to peer through web socket aur web rtc\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Or ya phir direct user upload karega server pe va se vo link share karega\n',
#  'Aniket Raje: Google Drive jaise\n',
#  'navinrajput: Abhi kya sikha raha hu\n',
#  'navinrajput: Kon year tumhara\n',
#  'Aniket Raje: Abhi main express kiya hu\n',
#  'Aniket Raje: Koi project bana ne wala hu\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Exam ke baad\n',
#  'Aniket Raje: React aur next basic kiya hai\n',
#  'navinrajput: Year kon sa tumahra\n',
#  'Aniket Raje: Abhi 4th sem main hu\n',
#  'Aniket Raje: 2nd year\n',
#  'Aniket Raje: July se 3rd year chalu ho raha hai\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Thik hai bro\n',
#  'navinrajput: Good night\n',
#  'Aniket Raje: Web rtc ke liye dennis ivy ke videos hai\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Webrtc based project best rahega\n',
#  'navinrajput: Thik hai\n',
#  'Aniket Raje: Kyuki bhut kam log ko ati hai\n',
#  'navinrajput: Haa\n',
#  'Aniket Raje: Bye\n',
#  'navinrajput: Bye\n',
#  'navinrajput: Hii bro\n',
#  'Aniket Raje: Hi\n',
#  'navinrajput: Bro koi notes banaya hai tumne\n',
#  'Aniket Raje: Konse\n',
#  'navinrajput: Data science mai\n',
#  'Aniket Raje: Rukho dekh tha hu\n',
#  'Aniket Raje: Mila toh bhejta hu\n',
#  'Aniket Raje: 2,3 topic ke upar hi banya tha\n',
#  'Aniket Raje: DOC-20240416-WA0000 (file attached)\n',
#  'navinrajput: Ok\n',
#  'navinrajput: ye hi hai\n',
#  'Aniket Raje: Aur linear regression and logistic ka hai\n',
#  'Aniket Raje: Baad main bhejta hu\n',
#  'navinrajput: ok\n',
#  'navinrajput: bro  share karon please\n',
#  'Aniket Raje: Bhai main bhar hu\n',
#  'Aniket Raje: Ghar jane ke baad karta hu\n',
#  'navinrajput: Ok bro\n',
#  'Aniket Raje: linear_regression_notes.pdf (file attached)\n',
#  'Aniket Raje: logistic_regression_notes.pdf (file attached)\n',
#  'navinrajput: Thanks bro\n',
#  'navinrajput: Bhai website ki tempalte kha se download karo free mai\n',
#  'Aniket Raje: Free template search karo\n',
#  'Aniket Raje: Bhut sari web sites hai\n',
#  'navinrajput: Haa bro but jaisi chahiye waisi nhi milti hai\n',
#  'navinrajput: hii bro docker kaha se sikho\n',
#  'Aniket Raje: Hitesh Chaudhary ki video hai dekho\n',
#  'navinrajput: ok\n',
#  'Aniket Raje: Hi bhai\n',
#  'navinrajput: Haa bhai\n',
#  'Aniket Raje: Amazon test diya kya apne\n',
#  'navinrajput: Haa\n',
#  'Aniket Raje: Kitne baje tha\n',
#  'navinrajput: Subha 9 baje\n',
#  'Aniket Raje: Mera abhi hai 7 baje\n',
#  'Aniket Raje: Kaise gya\n',
#  'navinrajput: Thik tha\n',
#  'navinrajput: Ml.ka theory ke 8 mcq tha math ka 12 mcq\n',
#  'Aniket Raje: Aapne chatgpt use kiya kya\n',
#  'Aniket Raje: Muje lagta hai mostly students cheating karenge\n',
#  'navinrajput: Kiya but utna possible nhi paya kyuki copy nhi hota hai question\n',
#  'Aniket Raje: Ok\n',
#  'Aniket Raje: Kitne candidate selecte honge 8000 main se\n',
#  'navinrajput: Pata nhi bro\n',
#  'Aniket Raje: Maine kahi padha tha 3000 honge\n',
#  'navinrajput: Accha hum bhi ho jaye tu\n',
#  'navinrajput: Math ke concept mai thoda ajib laga tha mujhe\n',
#  'navinrajput: Bhai kaisa gya test\n',
#  'Aniket Raje: Bhut hard gya mera\n',
#  'Aniket Raje: Bhai ek course main enroll karne ke liye itna kuch\n',
#  'Aniket Raje: Math kuch nhi ata muje toh\n',
#  'Aniket Raje: Aur ye log machine learning ati hai yesa samj ke  tha\n',
#  'navinrajput: Or kuch question math topic se alag tha\n',
#  'Aniket Raje: Ha\n',
#  'Aniket Raje: Mera toh nhi hoga\n',
#  'navinrajput: Mera bhi shayad hoga\n',
#  'Aniket Raje: Mera nhi hoga\n',
#  'Aniket Raje: I mean\n',
#  'navinrajput: Mera bhi kuch khe nhi skate hai\n',
#  'Aniket Raje: Chodo\n',
#  'navinrajput: Hm\n',
#  'Aniket Raje: Apne learning pe dyan denge\n',
#  'navinrajput: Haa\n',
#  'Aniket Raje: Main toh abhi dsa kar raha hu\n',
#  'navinrajput: Kon si language mai\n',
#  'Aniket Raje: Python\n',
#  'Aniket Raje: Bas concept pe dyan dena hai\n',
#  'navinrajput: Kha se kar rahu hu\n',
#  'Aniket Raje: Take u forward series\n',
#  'navinrajput: Wo c++ mai hai na\n',
#  'Aniket Raje: Ha lekin main code khud se kar raha hu\n',
#  'Aniket Raje: Aur unke website pe hai\n',
#  'Aniket Raje: Python ka\n',
#  'navinrajput: Python mai bhi video leacture\n',
#  'Aniket Raje: Problem solving techniques important hai\n',
#  'Aniket Raje: Nhi bas code hai\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Accha hai two language mai dsa hai\n',
#  'Aniket Raje: Nhi muje c++ nhi ati\n',
#  'Aniket Raje: Sirf python main\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Mai tu dono.mai karta hu\n',
#  'Aniket Raje: Sahi hai\n',
#  'navinrajput: Hmm\n',
#  'navinrajput: Hii\n',
#  'navinrajput: Bro mai socha raha hu ki r programming sikho tu koi best youtube channel hai bata oo\n',
#  'Aniket Raje: Bhai aap ko agar research main nhi jana hai toh r bilkul mat sikho abho\n',
#  'Aniket Raje: Par agar apko karna hai toh 365 data science ka course hai\n',
#  'Aniket Raje: Paid hai vo par apko telegram ya khi pe mil jaygea\n',
#  'navinrajput: Nhi mujhe research mai nhi jaana ye bus knowleadge ke liye\n',
#  'Aniket Raje: Mat sikho phir\n',
#  'Aniket Raje: Bhut confusing language hai beginner ke liye\n',
#  'Aniket Raje: Aap pehele python main hi machine learning, deep learning sikho\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Python best hai\n',
#  'navinrajput: Haa\n',
#  'navinrajput: Wo best hai\n',
#  'Aniket Raje: Bhut jan abhi R ko use nhi kar rahe\n',
#  'navinrajput: Hmm\n',
#  'Aniket Raje: Kyuki python main new libraries ayi hai jo R se best hai\n',
#  'navinrajput: Ok\n',
#  'navinrajput: hi\n',
#  'Aniket Raje: Hi\n',
#  'navinrajput: bro wo take forword mai python code kaha hai\n',
#  'Aniket Raje: Niche code tabs rehte hai\n',
#  'Aniket Raje: Solution page main\n',
#  'navinrajput: IMG-20240627-WA0006.jpg (file attached)\n',
#  'navinrajput: Ye\n',
#  'Aniket Raje: Dsa sheets>article\n',
#  'navinrajput: Ek kaam.karo link send kar do\n',
#  'Aniket Raje: https://takeuforward.org/data-structure/binary-search-explained/\n',
#  'navinrajput: Hii\n',
#  'navinrajput: Bro mail aaya tha tumko Amazon ka ml wala\n',
#  'Aniket Raje: Nhi\n',
#  'navinrajput: IMG-20240701-WA0004.jpg (file attached)\n',
#  'navinrajput: Ye aaya mujhe\n',
#  'Aniket Raje: This message was deleted\n',
#  'Aniket Raje: Muje bhi aya hai\n',
#  'Aniket Raje: Same\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Hii\n',
#  'navinrajput: Bro take u forward mai lecture bhi dekhate ho kya\n',
#  'Aniket Raje: Ha\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Hii bhai\n',
#  'navinrajput: Bhai fast api base project pata hai\n',
#  'Aniket Raje: Nhi bhai\n',
#  'Aniket Raje: Maine abhi tak fastapi use nhi kiya\n',
#  'navinrajput: koi resource pata hAI\n',
#  'Aniket Raje: Ruko dekha tu mila toh bheja hu\n',
#  'Aniket Raje: Mere bookmarks main se\n',
#  'Aniket Raje: Nhi hai bhai kuch\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Hii\n',
#  'navinrajput: Bro jo take u forward par se dsa karte hu tu code kaise python mai karte hu\n',
#  'Aniket Raje: Chatgpt\n',
#  'navinrajput: Tu phir logic kaise build hoga bhai\n',
#  'Aniket Raje: Pehle main try karta hu\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Nhi hua toh check karta hu\n',
#  'navinrajput: Fastapi ka mai project bana kuch idea hai\n',
#  'navinrajput: Tumko\n',
#  'Aniket Raje: Nhi\n',
#  'navinrajput: Koi Idea hai accha sa wo bata do\n',
#  'Aniket Raje: Peer to peer location tracking\n',
#  'navinrajput: Or hai koi\n',
#  'Aniket Raje: Event finder\n',
#  'Aniket Raje: Or meetup finder\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Hi\n',
#  'Aniket Raje: Hi bhai\n',
#  'navinrajput: Bhai tumne jo project Idea bata ya haina thoda sa unique id bata duna bhai\n',
#  'Aniket Raje: Bhai muje khud ko abhi project bana na hai. Aur koi idea ah nhi raha\n',
#  'Aniket Raje: Aya toh batunga dunga apko\n',
#  'Aniket Raje: Apko koi idea mila toh muje bhi batana\n',
#  'navinrajput: Nhi bhai mujhe deadline hai Tuesday ko\n',
#  'Aniket Raje: Main car renting pe kuch bana ne ka soch raha hu\n',
#  'Aniket Raje: Zoomcar type\n',
#  'navinrajput: Car rental wala tu jab bca mai tha tu ek friend ka banaya tha\n',
#  'Aniket Raje: Ya phir import export sellers finder\n',
#  'navinrajput: Bro koi site pata hai jaha par se idea mile\n',
#  'Aniket Raje: https://www.crio.do/projects/?utm_source=adwords&gclid=CjwKCAiA3KefBhByEiwAi2LDHG1E6ZlzpPVS_jFbDTKSZ78BzHoqxStYSKIb0quJqEoUzckZZOgsnRoCK9QQAvD_BwE\n',
#  'Aniket Raje: https://projectlearn.io/#categories\n',
#  'navinrajput: Ye tu dekha ismai ek project hai wo dekho tum chatbot dong recommends\n',
#  'Aniket Raje: https://projectworlds.in/\n',
#  'Aniket Raje: Aap kis ke liye bana rahe ho\n',
#  'Aniket Raje: Main college project ke liye bana raha hu\n',
#  'navinrajput: Final year project\n',
#  'navinrajput: Same\n',
#  'Aniket Raje: 2min main ek dekhta hu\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: https://www.linkedin.com/posts/activity-7064214812951482368-tAXa?utm_source=share&utm_medium=member_android\n',
#  'navinrajput: Movie recommendations system hai\n',
#  'Aniket Raje: Nhi voice dubbing type kuch hai\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Hii\n',
#  'Aniket Raje: Hi\n',
#  'navinrajput: Bhai ml ke basic theory ki notes hai like type of ml and other topics\n',
#  'Aniket Raje: Nhi bhai\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Campusx ke\n',
#  'Aniket Raje: Website pe mil jayega\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Jo tumne mujhe phele notes bej the wo hi tumhare paas ya dusri koi aur note bhi hai\n',
#  'Aniket Raje: Vhi hai\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Math ke banaya the\n',
#  'navinrajput: Kya\n',
#  'Aniket Raje: Nhi\n',
#  'Aniket Raje: Math mene kiya nhi\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Data analysis or data engineer ka roadmap\n',
#  'Aniket Raje: https://roadmap.sh/data-analyst\n',
#  'navinrajput: Data engineer ka hai\n',
#  'Aniket Raje: Nhi\n',
#  'navinrajput: Hii\n',
#  'Aniket Raje: Hi\n',
#  'navinrajput: Nothing bro\n',
#  'navinrajput: Hii\n',
#  'Aniket Raje: Hi\n',
#  'Aniket Raje: Bhai dusra kon kon hai interested\n',
#  'navinrajput: Bhai idea nhi mujhe\n',
#  'Aniket Raje: Please pucho kisko ko koi interested hai kya\n',
#  'Aniket Raje: Aur 2 log chaiye hume\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Hi bhai koi 1 bhi nhi hai kya\n',
#  'Aniket Raje: Jo aa skta hai\n',
#  'navinrajput: Nhi bhai\n',
#  'Aniket Raje: Kya karna phir\n',
#  'navinrajput: Bhai mai soch raha mai rhen de kyu mera tu placement bhi start hai tu mai jada dhyan nhi de punga shayad\n',
#  'Aniket Raje: Ok\n',
#  'navinrajput: Hii bro\n',
#  'Aniket Raje: Hi\n',
#  'navinrajput: Bro tumko intership karni hai kya\n',
#  'Aniket Raje: Ha\n',
#  'navinrajput: Bhai tu job hunting chalu kare\n',
#  'Aniket Raje: Ok\n',
#  'navinrajput: Haa bro linkdin par or koi platform pata hai tumko\n',
#  'navinrajput: Ek tu intereshal hai\n',
#  'Aniket Raje: Naukri, indeed, unstop\n',
#  'navinrajput: Thik aaj account bana te hai aur start karte hai\n',
#  'Aniket Raje: Maine banya hai\n',
#  'navinrajput: Mera indeed par unstop aur naukari par nhi hai\n',
#  'Aniket Raje: Ok\n',
#  'Aniket Raje: Banv phir\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Follow the Krishan Kumar - Jobs & Internships Updates channel on WhatsApp: https://whatsapp.com/channel/0029Va6I79K60eBfQ92DwH0W\n',
#  'Aniket Raje: Follow the TECH CAREER  {Jobs | Internships | Upskill} channel on WhatsApp: https://whatsapp.com/channel/0029Va982CH6hENxVXZzuX14\n',
#  'navinrajput: Bro done\n',
#  'Aniket Raje: Bhai apka resume send karo na\n',
#  'navinrajput: Wait\n',
#  'navinrajput: Navin Rajput Resume.pdf (file attached)\n',
#  'navinrajput: Kaisa hai\n',
#  'Aniket Raje: Acha hai\n',
#  'Aniket Raje: Bas ab internship karni hai\n',
#  'Aniket Raje: Hume\n',
#  'navinrajput: Hmm\n',
#  'navinrajput: https://unstop.com/o/xB4bNvw?lb=5bVhETkf&utm_medium=Share&utm_source=shortUrl\n',
#  'navinrajput: Hii\n',
#  'Aniket Raje: Hi bro\n',
#  'navinrajput: Bhai wo jo take u forward ka dsa karte hu mujhe thoda bata na kaisa karte hu kyu mujhe pura logic nhi banta hai use isa liye\n',
#  'Aniket Raje: Main pehle takeuforward channel pe video dekh tha hu, phir uska code likhne kha try karta hu, nhi hua toh phirse video dekh tha hu\n',
#  'navinrajput: Bhai tu jada time waste nhi hota hai\n',
#  'Aniket Raje: Ha\n',
#  'Aniket Raje: Bas pattern yaad rakhne kha try karta hu\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: DOC-20240505-WA0002 (file attached)\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Bhai neetcode io ka playlist bhi acha hau\n',
#  'Aniket Raje: Hai*\n',
#  'navinrajput: Haa dekha ta hu\n',
#  'navinrajput: Hii\n',
#  'navinrajput: Bhai mai kuch soch raha tha ki hum 2 ,4 milkar ek ya doo data science field mai unique project banaye\n',
#  'Aniket Raje: Ha\n',
#  'navinrajput: Tu hum theen log milkar banate hai\n',
#  'Aniket Raje: Kon hai aur\n',
#  'navinrajput: Bhai mai aur tum aur abhi\n',
#  'Aniket Raje: Ok\n',
#  'Aniket Raje: Koi idea soch hai\n',
#  'navinrajput: Bhai mai tu soch raha jo smart india hackathon mai bhut sare idea hai tu usko category wise search karte hai usmai se ek do find karte hai\n',
#  'Aniket Raje: Ml related jyda nhi hai\n',
#  'Aniket Raje: Humne dekha tha\n',
#  'Aniket Raje: Sar image colorization, deepfake detection\n',
#  'Aniket Raje: Aur ek hai\n',
#  'navinrajput: Haa tu dekhate hai aur kahi se mile tu\n',
#  'Aniket Raje: Ok\n',
#  'navinrajput: https://www.expertia.ai/zenconsultancy-net/job/hiring-data-science-interns-66653a7f99c001756d25237a?utm_source=linkedin-feed&easy_apply=true&date-refresh=09/24/2024\n',
#  'navinrajput: https://app.soulhq.ai/?campus=data-scientists\n',
#  'navinrajput: Bhai ye do company ka mila mujhe linkdin se\n',
#  'Aniket Raje: Ok\n',
#  'navinrajput: Bhai koi project mila\n',
#  'Aniket Raje: Nhi\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Hii\n',
#  'Aniket Raje: Hello\n',
#  'navinrajput: Bhai abhi group mai company dala data science ke role ke apply kare kya\n',
#  'Aniket Raje: Online hai ya off\n',
#  'Aniket Raje: Offline\n',
#  'navinrajput: Idea nhi mujhe ek baar tum dekho na\n',
#  'Aniket Raje: Ok\n',
#  'navinrajput: Hii\n',
#  'Aniket Raje: Bhai mera abhi exams  hai toh main jyda dyan nhi de paunga\n',
#  'navinrajput: Hii bhai\n',
#  'Aniket Raje: Hi\n',
#  'navinrajput: Puri ho gi exam\n',
#  'Aniket Raje: Nhi\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Kya hua\n',
#  'navinrajput: Nhi wo internship or job ke apply karne ke liye pucha khai kiya tumne\n',
#  'Aniket Raje: Main try kar raha hu har jagh\n',
#  'Aniket Raje: Aap welfound pe bhi apply karo\n',
#  'navinrajput: Bhai tu link bej diya karo mujhe\n',
#  'Aniket Raje: Maine bhi kiya hai\n',
#  'Aniket Raje: Are bhai muje yaad nhi tha\n',
#  'Aniket Raje: Sorry\n',
#  'navinrajput: Ok\n',
#  'Aniket Raje: Wellfound try karo\n',
#  'navinrajput: Mai kya bol  ats friendly resume mera ho nhi rahi apna ek baar bejna\n',
#  'Aniket Raje: 66e40dd732453_aniket-raje-resume-compressed.docx (file attached)\n',
#  'Aniket Raje: Mera full stack oriented hai resume\n',
#  'navinrajput: Ok\n',
#  'navinrajput: Mai tu Full stack python developer ka or data science ka bano ga\n',
#  'Aniket Raje: Ok\n',
#  'navinrajput: Bhai mera resume ka review karna ek baar bejta hu\n',
#  'navinrajput: Navin Rajput Resume.pdf (file attached)\n',
#  'Aniket Raje: Bhai badiya hai mere se toh\n',
#  'navinrajput: Bhai abhi kisi company mai apply kiya hai\n',
#  'Aniket Raje: Nhi\n',
#  'navinrajput: Hii bhai\n',
#  'navinrajput: IMG-20241103-WA0003.jpg (file attached)\n',
#  'Aniket Raje: Bhai thik se check karo aaj kal bhut scam chal rahe hai\n',
#  'navinrajput: Bhai maine company dekhi abhi\n',
#  'Aniket Raje: Toh\n',
#  'navinrajput: Ek baar tum linkdin par dekho usmai opening bhi chalu hai\n',
#  'Aniket Raje: Link send karo na\n',
#  'navinrajput: https://www.linkedin.com/company/try-outlier/\n',
#  'navinrajput: Ye company linkdin Page hai\n',
#  'Aniket Raje: Apne apply kiya kya\n',
#  'navinrajput: Nhi but jo maine sc beja tha wo usmai work karti hai or refer karna chahti apni company mai\n',
#  'Aniket Raje: Toh bolo karne ko\n',
#  'Aniket Raje: Dekhte hai kya hota hai\n',
#  'navinrajput: Bola hai details share kar du kya manga hai\n',
#  'Aniket Raje: Kardo\n',
#  'navinrajput: Ok\n',
#  'navinrajput: https://www.expertia.ai/skillsecureai-in/job/hiring-data-science-intern-67274e2abe018adcf890e4be?utm_source=linkedin-feed&easy_apply=true\n',
#  'navinrajput: IMG-20241104-WA0001.jpg (file attached)\n',
#  'Aniket Raje: Kya hua\n',
#  'navinrajput: Bhai ye email aaya tha company ki taraf se\n',
#  'navinrajput: But wo log remote job offer kar raha hai as coder or ai trainer\n',
#  'Aniket Raje: Toh apko nhi chaiye kya\n',
#  'navinrajput: Bhai wo hi socha raha hu kya karo\n',
#  'Aniket Raje: Pay kitna kar rahe hai\n',
#  'Aniket Raje: Ya interview hone wala hai\n',
#  'Aniket Raje: Kardo bhai remote acha rhega\n',
#  'navinrajput: Form fill karne ko kha hai uske baad ek assesment hoga or interview the start work\n',
#  'Aniket Raje: Ok\n',
#  'Aniket Raje: Kardo\n',
#  'Aniket Raje: Kya socha hai apne\n',
#  'navinrajput: Bhai office wala hotu jada accha rahaga dekhta hu apply kar deta hu jo hoga dekha jayega\n',
#  'Aniket Raje: Kardo bhai\n',
#  'Aniket Raje: Experience main hai\n',
#  'Aniket Raje: Baad main switch kar sakte hai\n',
#  'Aniket Raje: Apne internships ki hai kya pehle\n',
#  'navinrajput: Freelancing type hai\n',
#  'Aniket Raje: Ha\n',
#  'navinrajput: Haa isliye socha raha hu ki karo ya na karo\n',
#  'Aniket Raje: Dekho\n',
#  'navinrajput: Main le tarun bhai se pucha tha une bhi bola try kar nhi man kiya tu chod dena\n',
#  'Aniket Raje: Vhi\n',
#  'Aniket Raje: Kuch na karne se acha hai\n',
#  'navinrajput: Hmm\n',
#  'navinrajput: null\n',
#  'Aniket Raje: Call kiya tha\n',
#  'navinrajput: Glati tap ho ga ya\n']

# %%
dates = re.findall(pattern, data)

# %%
df = pd.DataFrame({'user_message': messages, 'message_date': dates})
df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%Y, %H:%M - ')
df.rename(columns={'message_date': 'date'}, inplace=True)
df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. N... 2024-01-06 13:56:00
# 1                      navinrajput: Hii aniket bro\n 2024-01-23 22:16:00
# 2                           Aniket Raje: Bolo bhai\n 2024-01-23 22:17:00
# 3  navinrajput: Bro tumne web development chalu h... 2024-01-23 22:17:00
# 4                                  Aniket Raje: Ha\n 2024-01-23 22:17:00

# %%
df.shape
# Out:
# (727, 2)

# %%
users = []
messages = []
for message in df['user_message']:
    entry = re.split(r'([\w\W]+?):\s', message)
    if entry[1:]:  # user name
        users.append(entry[1])
        messages.append(" ".join(entry[2:]))
    else:
        users.append('group_notification')
        messages.append(entry[0])

# %%
df['user'] = users
df['message'] = messages
df.drop(columns=['user_message'], inplace=True)
df.head()
# Out:
#                  date                user  \
# 0 2024-01-06 13:56:00  group_notification
# 1 2024-01-23 22:16:00         navinrajput
# 2 2024-01-23 22:17:00         Aniket Raje
# 3 2024-01-23 22:17:00         navinrajput
# 4 2024-01-23 22:17:00         Aniket Raje
#
#                                              message
# 0  Messages and calls are end-to-end encrypted. N...
# 1                                   Hii aniket bro\n
# 2                                        Bolo bhai\n
# 3              Bro tumne web development chalu hai\n
# 4                                               Ha\n

# %%
df['only_date'] = df['date'].dt.date

# %%
df['year'] = df['date'].dt.year

# %%
df['month_num'] = df['date'].dt.month

# %%
df['month'] = df['date'].dt.month_name()

# %%
df['day'] = df['date'].dt.day

# %%
df['day_name'] = df['date'].dt.day_name()

# %%
df['hour'] = df['date'].dt.hour

# %%
df['minute'] = df['date'].dt.minute

# %%
df.head()
# Out:
#                  date                user  \
# 0 2024-01-06 13:56:00  group_notification
# 1 2024-01-23 22:16:00         navinrajput
# 2 2024-01-23 22:17:00         Aniket Raje
# 3 2024-01-23 22:17:00         navinrajput
# 4 2024-01-23 22:17:00         Aniket Raje
#
#                                              message   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2024-01-06  2024
# 1                                   Hii aniket bro\n  2024-01-23  2024
# 2                                        Bolo bhai\n  2024-01-23  2024
# 3              Bro tumne web development chalu hai\n  2024-01-23  2024
# 4                                               Ha\n  2024-01-23  2024
#
#    month_num    month  day  day_name  hour  minute
# 0          1  January    6  Saturday    13      56
# 1          1  January   23   Tuesday    22      16
# 2          1  January   23   Tuesday    22      17
# 3          1  January   23   Tuesday    22      17
# 4          1  January   23   Tuesday    22      17

# %%
period = []
for hour in df[['day_name', 'hour']]['hour']:
    if hour == 23:
        period.append(str(hour) + "-" + str('00'))
    elif hour == 0:
        period.append(str('00') + "-" + str(hour + 1))
    else:
        period.append(str(hour) + "-" + str(hour + 1))
df['period'] = period
